# %%
import pandas as pd

file_path = r"Dataset\comparison_outputs\use\Movies-Dataset-no-missing-2000-2026-ML-Ready.csv"

columns = pd.read_csv(file_path, nrows=0).columns.tolist()
print(columns)
# Out:
# ['title', 'genres', 'original_language', 'overview', 'popularity', 'production_companies', 'release_date', 'budget', 'runtime', 'status', 'tagline', 'vote_average', 'vote_count', 'keywords', 'adult', 'production_countries', 'spoken_languages', 'actor_1_popularity', 'actor_2_popularity', 'actor_3_popularity', 'mpaa_rating', 'revenue']

# %%
print(len(columns))
# Out:
# 22
